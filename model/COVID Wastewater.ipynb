# %%
import pandas as pd
import plotly.graph_objects as go
import numpy as np
import plotly.io as pio
pio.renderers.default = 'iframe'
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# # CDC Data

# %%
def get_cdc_data(url="https://data.cdc.gov/api/views/2ew6-ywp6/rows.csv"):
    df = pd.read_csv(url)
    df = df[df.wwtp_jurisdiction == "New York City"]
    df['test_date'] = pd.to_datetime(df.date_end)
    df = df.drop(['first_sample_date', 'reporting_jurisdiction', 'sample_location', 'sample_location_specify', 'county_fips', 'detect_prop_15d', 'sampling_prior'], axis=1)
    return df

# %%
cdc_df = get_cdc_data()

# %%
cdc_df.head()
# Out:
#      wwtp_jurisdiction  wwtp_id  \
# 5162     New York City      545
# 5163     New York City      545
# 5164     New York City      545
# 5165     New York City      545
# 5166     New York City      545
#
#                                             key_plot_id county_names  \
# 5162  CDC_BIOBOT_ny_545_Treatment plant_post grit re...       Queens
# 5163  CDC_BIOBOT_ny_545_Treatment plant_post grit re...       Queens
# 5164  CDC_BIOBOT_ny_545_Treatment plant_post grit re...       Queens
# 5165  CDC_BIOBOT_ny_545_Treatment plant_post grit re...       Queens
# 5166  CDC_BIOBOT_ny_545_Treatment plant_post grit re...       Queens
#
#       population_served  date_start    date_end  ptc_15d  percentile  \
# 5162             728123  2022-05-29  2022-06-12      NaN        68.0
# 5163             728123  2022-05-30  2022-06-13      NaN        68.0
# 5164             728123  2022-05-31  2022-06-14    363.0        72.5
# 5165             728123  2022-06-01  2022-06-15    363.0        72.5
# 5166             728123  2022-06-02  2022-06-16    363.0        72.5
#
#       test_date
# 5162 2022-06-12
# 5163 2022-06-13
# 5164 2022-06-14
# 5165 2022-06-15
# 5166 2022-06-16

# %% [markdown]
# # NYC data exploration

# %%
wwtp_mapping={
    "26th Ward": 485,
    "Bowery Bay":487,
    "Coney Island":541,
    "Hunts Point":498,
    "Jamaica Bay":545,
    "Newtown Creek":549,
    "North River": 500, #JUST PICKING ONE FOR NOW, COULD BE 509
    "Oakwood Beach":550,
    "Owls Head":551,
    "Port Richmond":552,
    "Red Hook":553,
    "Rockaway":503,
    "Tallman Island":505,
    "Wards Island": 509 #JUST PICKING ONE FOR NOW, COULD BE 500
}

# %%
def get_nyc_data(url="https://data.cityofnewyork.us/api/views/f7dc-2q9f/rows.csv"):
    df = pd.read_csv(url)
    df['test_date'] = pd.to_datetime(df['Test date'])
    df['wwtp_id'] = df['WRRF Name'].map(wwtp_mapping)
    df = df.drop(['WRRF Abbreviation','Sample Date'], axis=1)
    # ADD NEW ANNOTATION REVIEW FLOW
    df=df.rename(columns={'Technology':'technology','Sample date':'sample_date', 'WRRF Name':'wrrf_name', 'Concentration SARS-CoV-2 gene target (N1 Copies/L) ':'covid_conc', 'Per capita SARS-CoV-2 load (N1 copies per day per population)':'per_capita_covid_conc', 'Annotation':'annotation', 'Population Served, estimated ':'pop_serv_est'})
    df = df[~df.annotation.isin(['Possible analytical issue', 'Concentration below Method Limit of Detection', 'No signal detected; possible analytical issue',
       'No sample delivery due to logistical issue', 'Sample was not analyzed due to ongoing study with NYC-DOHMH', 'Analytical issue', 'Concentration below Method Limit of Quantification (above Method Limit of Detection)', 'This result is not useable (because associated with contaminated method blank)', 'Concentration below Method Limit of Quantification (above Method Limit of Detection)', 'Sample exhibited unusual (redish) color upon arrival.', 'This batch of samples was not analyzed due to short of staff.'])]
    return df

# %%
def get_nyc_perc_dPCR(df):
    df = df[df['technology'] == 'dPCR']
    df['cum_max'] = df.groupby('wwtp_id')['covid_conc'].cummax()
    rolling = df.set_index('test_date').groupby('wwtp_id')['covid_conc'].rolling('14D').mean().reset_index().rename(columns={'covid_conc':'covid_conc_14d'})
    df = pd.merge(df, rolling, on=['test_date', 'wwtp_id'])
    df['est_percentile'] = np.round((df['covid_conc_14d'] / df['cum_max']) * 100, 1)
    return df

# %%
def get_nyc_perc_RTPCR(df):
    df = df[df['technology'] == 'RT-qPCR']
    #df['covid_conc_adj'] = df['covid_conc'] * 15
    df['cum_max'] = df.groupby('wwtp_id')['covid_conc'].cummax()
    rolling = df.set_index('test_date').groupby('wwtp_id')['covid_conc'].rolling('14D').mean().reset_index().rename(columns={'covid_conc':'covid_conc_14d'})
    df = pd.merge(df, rolling, on=['test_date', 'wwtp_id'])
    df['est_percentile'] = np.round((df['covid_conc_14d'] / df['cum_max']) * 100, 1)
    return df

# %%
def nyc_main():
    # Wait for burn in period before using both datasets, official cut over to dpcr is March 2023
    # Eliminate data from before Spring 2021, because the percentiles look crazy
    nyc_df = get_nyc_data()
    rtpcr_df = get_nyc_perc_RTPCR(nyc_df)
    dpcr_df = get_nyc_perc_dPCR(nyc_df)
    df = pd.merge(dpcr_df[dpcr_df.test_date > "2023-01-01"], rtpcr_df[(rtpcr_df.test_date > "2021-06-01")& (rtpcr_df.test_date < "2023-03-01")], \
                  on=['test_date', 'wwtp_id', 'pop_serv_est'], how='outer', suffixes=('_dpcr', '_rtpcr'))
    df['est_percentile'] = df['est_percentile_rtpcr'].fillna(df['est_percentile_dpcr'])
    df = df.drop(['est_percentile_dpcr', 'est_percentile_rtpcr'], axis=1)
    df = df[['test_date', 'wwtp_id', 'est_percentile', 'pop_serv_est']]
    return df

# %%
nyc_df = nyc_main()
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# # Merged Data

# %%
wwtp_county_mapping = {
    485:"Kings",
    487:"Queens",
    498:"Bronx",
    500:"New York",
    503:"Queens",
    505:"Queens",
    509:"New York",
    541:"Kings",
    545:"Queens",
    549:"Kings",
    550:"Richmond",
    551:"Kings",
    552:"Richmond", 
    553:"Kings"
}

# %%
def merge_cdc_nyc(cdc_df, nyc_df):
    # CDC data only used after March, because their percentiles are too high before that -- burn in effect
    df = pd.merge(cdc_df[cdc_df.test_date > '2023-04-01'], nyc_df[nyc_df.test_date < '2023-04-01'], on=['test_date', 'wwtp_id'], how="outer")
    df['merged_percentile'] = df['percentile'].fillna(df['est_percentile'])
    df['merged_population'] = df['population_served'].fillna(df['pop_serv_est'])
    df['county'] = df['wwtp_id'].map(wwtp_county_mapping)
    return df[['test_date', 'wwtp_id', 'merged_percentile', 'merged_population', 'county']]

# %%
df = merge_cdc_nyc(cdc_df, nyc_df)

# %% [markdown]
# # Aggregate

# %%
def overall_weighted_average(df):
    return grouped_weighted_avg(df.merged_percentile, df.merged_population, df.test_date).to_frame('NYC_percentile')

# %%
def grouped_weighted_avg(values, weights, by):
    return (values * weights).groupby(by).sum() / weights.groupby(by).sum()

# %%
def weighted_avg_by_borough(df):
    borough_df = pd.DataFrame()
    for county in ['Richmond', 'Queens', 'Kings', 'Bronx', 'New York']:
        data = df[df.county == county]
        borough_df[county + '_w_percentile'] = grouped_weighted_avg(data.merged_percentile, data.merged_population, data.test_date)
    return borough_df

# %%
def main():
    cdc_df = get_cdc_data()
    nyc_df = nyc_main()
    df = merge_cdc_nyc(cdc_df, nyc_df)
    agg_df = overall_weighted_average(df)
    borough_df = weighted_avg_by_borough(df)
    df = agg_df.join(borough_df)
    return df

# %%
t = main()
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
t.tail(20)
# Out:
#             NYC_percentile  Richmond_w_percentile  Queens_w_percentile  \
# test_date
# 2023-08-28       39.597125              43.368658            43.561169
# 2023-08-29       40.873690              45.399682            43.969717
# 2023-08-30       40.873690              45.399682            43.969717
# 2023-08-31       40.873690              45.399682            43.969717
# 2023-09-01       40.873690              45.399682            43.969717
# 2023-09-02       40.873690              45.399682            43.969717
# 2023-09-03       40.873690              45.399682            43.969717
# 2023-09-04       40.873690              45.399682            43.969717
# 2023-09-05       45.747604              47.922042            44.810950
# 2023-09-06       45.747604              47.922042            44.810950
# 2023-09-07       45.747604              47.922042            44.810950
# 2023-09-08       45.747604              47.922042            44.810950
# 2023-09-09       45.747604              47.922042            44.810950
# 2023-09-10       46.162564              48.462469            46.033376
# 2023-09-11       46.162564              48.462469            46.033376
# 2023-09-12       48.564261              49.324268            47.714675
# 2023-09-13       48.564261              49.324268            47.714675
# 2023-09-14       48.564261              49.324268            47.714675
# 2023-09-15       48.564261              49.324268            47.714675
# 2023-09-16       48.564261              49.324268            47.714675
#
#             Kings_w_percentile  Bronx_w_percentile  New York_w_percentile
# test_date
# 2023-08-28           40.780354               29.40                 34.200
# 2023-08-29           43.113984               30.20                 34.400
# 2023-08-30           43.113984               30.20                 34.400
# 2023-08-31           43.113984               30.20                 34.400
# 2023-09-01           43.113984               30.20                 34.400
# 2023-09-02           43.113984               30.20                 34.400
# 2023-09-03           43.113984               30.20                 34.400
# 2023-09-04           43.113984               30.20                 34.400
# 2023-09-05           48.914173               37.00                 43.875
# 2023-09-06           48.914173               37.00                 43.875
# 2023-09-07           48.914173               37.00                 43.875
# 2023-09-08           48.914173               37.00                 43.875
# 2023-09-09           48.914173               37.00                 43.875
# 2023-09-10           47.384114               41.25                 45.375
# 2023-09-11           47.384114               41.25                 45.375
# 2023-09-12           50.593925               44.75                 47.000
# 2023-09-13           50.593925               44.75                 47.000
# 2023-09-14           50.593925               44.75                 47.000
# 2023-09-15           50.593925               44.75                 47.000
# 2023-09-16           50.593925               44.75                 47.000

# %%
df = t.reset_index()
fig = go.Figure()
for county in ['Richmond', 'Queens', 'Kings', 'Bronx', 'New York']:
    data = df[df[county + '_w_percentile'] == county]
    fig.add_trace(go.Scatter(x=df.test_date, y=df[county + '_w_percentile'], name=county, line=dict(width=4)))
fig.add_trace(go.Scatter(x=df.test_date, y=df.NYC_percentile, name="All Watersheds", line=dict(color='black', width=4)))
fig.add_vline(x="2023-03-01", line_dash="dot")
fig.add_vrect(x0="2021-07-15", x1="2021-09-10", annotation_text="Delta Wave", annotation_position="top left",
              fillcolor="green", opacity=0.25, line_width=0)
fig.add_vrect(x0="2021-12-01", x1="2022-02-01", annotation_text="Omicron Wave", annotation_position="top left",
              fillcolor="green", opacity=0.25, line_width=0)
fig.update_yaxes(range=[0,100])
fig.update_layout(
    title=dict(text="Two Week Weighted COVID Wastewater Percentile Rate by Borough", yref='paper')
)
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/core/ops/__init__.py:1115: FutureWarning:
#
# elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_22.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
#### EVERYTHING BELOW HERE IS JUST NOTES

# %% [markdown]
# # Plots

# %%
df[(nyc_df.wwtp_id == 549)].tail()
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#      wwtp_jurisdiction  wwtp_id  \
# 2068     New York City      551
# 2081     New York City      551
# 2094     New York City      551
# 2107     New York City      551
# 2120     New York City      551
#
#                                             key_plot_id county_names  \
# 2068  CDC_BIOBOT_ny_551_Treatment plant_post grit re...        Kings
# 2081  CDC_BIOBOT_ny_551_Treatment plant_post grit re...        Kings
# 2094  CDC_BIOBOT_ny_551_Treatment plant_post grit re...        Kings
# 2107  CDC_BIOBOT_ny_551_Treatment plant_post grit re...        Kings
# 2120  CDC_BIOBOT_ny_551_Treatment plant_post grit re...        Kings
#
#       population_served  date_start    date_end  ptc_15d  percentile  \
# 2068             758007  2023-03-06  2023-03-20    -33.0       27.80
# 2081             758007  2023-03-15  2023-03-29    -58.0       22.40
# 2094             758007  2023-03-29  2023-04-12    -20.0       13.40
# 2107             758007  2023-05-22  2023-06-05    -15.0        8.25
# 2120             758007  2023-07-12  2023-07-26    135.0       34.40
#
#      sample_date  ...   Test date  wrrf_name covid_conc_x  \
# 2068  2023-03-20  ...  03/20/2023  Owls Head       3570.0
# 2081  2023-03-29  ...  03/29/2023  Owls Head      96288.0
# 2094  2023-04-12  ...  04/12/2023  Owls Head      42744.0
# 2107  2023-06-05  ...  06/05/2023  Owls Head      57552.0
# 2120  2023-07-26  ...  07/26/2023  Owls Head     132672.0
#
#       per_capita_covid_conc  annotation pop_serv_est  Technology   cum_max  \
# 2068              1250000.0         NaN       906442     RT-qPCR  124846.0
# 2081             32600000.0         NaN       906442        dPCR  855360.0
# 2094             13900000.0         NaN       906442        dPCR  855360.0
# 2107             19900000.0         NaN       906442        dPCR  855360.0
# 2120             52600000.0         NaN       906442        dPCR  855360.0
#
#       perc_test   covid_conc_y
# 2068      199.0  248423.333333
# 2081        0.7    5883.000000
# 2094        0.6    5540.000000
# 2107       10.7   91576.000000
# 2120       11.8  100608.000000
#
# [5 rows x 21 columns]

# %%
nyc_df[(nyc_df.wwtp_id == 549)].tail()
# Out:
#        Test date      wrrf_name  covid_conc  per_capita_covid_conc  \
# 3911  07/19/2023  Newtown Creek    115344.0             83400000.0
# 3925  07/24/2023  Newtown Creek    120360.0             70500000.0
# 3939  07/26/2023  Newtown Creek    106128.0             84100000.0
# 3953  07/31/2023  Newtown Creek    125328.0             72600000.0
# 3967  08/02/2023  Newtown Creek    135504.0                    NaN
#
#                                   annotation  pop_serv_est Technology  \
# 3911  This sample was analyzed in duplicate.       1156473       dPCR
# 3925  This sample was analyzed in duplicate.       1156473       dPCR
# 3939  This sample was analyzed in duplicate.       1156473       dPCR
# 3953  This sample was analyzed in duplicate.       1156473       dPCR
# 3967  This sample was analyzed in duplicate.       1156473       dPCR
#
#       test_date  wwtp_id
# 3911 2023-07-19    549.0
# 3925 2023-07-24    549.0
# 3939 2023-07-26    549.0
# 3953 2023-07-31    549.0
# 3967 2023-08-02    549.0

# %%
135504.0 / 333840.0
# Out:
# 0.40589503953989936

# %%
cdc

# %%
fig = go.Figure()
for county in ['Richmond', 'Queens', 'Kings', 'Bronx', 'New York']:
    data = df[df.county_names == county]
    avg = grouped_weighted_avg(data.percentile, data.population_served, data.date_end).to_frame('percentile').reset_index()
    fig.add_trace(go.Scatter(x=avg.date_end, y=avg.percentile, name=county, line=dict(width=4)))
fig.add_trace(go.Scatter(x=w.date_end, y=w.percentile, name="All Watersheds", line=dict(color='black', width=4)))

fig.update_yaxes(range=[0,100])
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_96.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
nbk_watersheds = df[df.wwtp_id.isin([553, 549])]

# %%
for wwtp_id in nbk_watersheds.wwtp_id.unique():
    data = nbk_watersheds[nbk_watersheds.wwtp_id == wwtp_id]
    fig.add_trace(go.Scatter(x=data.date_end, y=data.percentile, name=wwtp_id.astype('str')))

# %%
import pandas as pd 

df = pd.read_csv("./output.csv")
json = df.to_json("./output_json.json", orient="columns")

# %%
fig
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_99.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
import matplotlib.pyplot as plt # Impot the relevant module

fig, ax = plt.subplots() # Create the figure and axes object

# Plot the first x and y axes:
df.plot(x = 'test_date', y = 'percentile', ax = ax) 
# Plot the second x and y axes. By secondary_y = True a second y-axis is requested:
# (see https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.html for details)
df.plot(x = 'test_date', y = 'covid_conc', ax = ax, secondary_y = True)

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
df_sk = df[(df['percentile'].notnull()) & (df['per_capita_covid_conc'].notnull())]

# %%
features = df_sk['percentile'].values.reshape(-1,1)
target = df_sk['per_capita_covid_conc'].values.reshape(-1,1)

# %%
features_train, features_test, target_train, target_test = train_test_split(features, target, test_size=0.2, random_state=0)

# %%
model = LinearRegression()
model.fit(features_train, target_train)
# Out:
# LinearRegression()

# %%
target_pred = model.predict(features_test)

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(target_test, target_pred))
print('Mean Squared Error:', metrics.mean_squared_error(target_test, target_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(target_test, target_pred)))
# Out:
# Mean Absolute Error: 26303879.0271384
# Mean Squared Error: 1811829201638000.2
# Root Mean Squared Error: 42565587.058538266

# %%
cdc_df[cdc_df.wwtp_id == 551].tail(30)
# Out:
#        wwtp_jurisdiction  wwtp_id  \
# 737985     New York City      551
# 737986     New York City      551
# 737987     New York City      551
# 737988     New York City      551
# 737989     New York City      551
# 737990     New York City      551
# 737991     New York City      551
# 737992     New York City      551
# 737993     New York City      551
# 737994     New York City      551
# 737995     New York City      551
# 737996     New York City      551
# 737997     New York City      551
# 737998     New York City      551
# 737999     New York City      551
# 738000     New York City      551
# 738001     New York City      551
# 738002     New York City      551
# 738003     New York City      551
# 738004     New York City      551
# 738005     New York City      551
# 738006     New York City      551
# 738007     New York City      551
# 738008     New York City      551
# 738009     New York City      551
# 738010     New York City      551
# 738011     New York City      551
# 738012     New York City      551
# 738013     New York City      551
# 738014     New York City      551
#
#                                               key_plot_id county_names  \
# 737985  CDC_BIOBOT_ny_551_Treatment plant_post grit re...        Kings
# 737986  CDC_BIOBOT_ny_551_Treatment plant_post grit re...        Kings
# 737987  CDC_BIOBOT_ny_551_Treatment plant_post grit re...        Kings
# 737988  CDC_BIOBOT_ny_551_Treatment plant_post grit re...        Kings
# 737989  CDC_BIOBOT_ny_551_Treatment plant_post grit re...        Kings
# 737990  CDC_BIOBOT_ny_551_Treatment plant_post grit re...        Kings
# 737991  CDC_BIOBOT_ny_551_Treatment plant_post grit re...        Kings
# 737992  CDC_BIOBOT_ny_551_Treatment plant_post grit re...        Kings
# 737993  CDC_BIOBOT_ny_551_Treatment plant_post grit re...        Kings
# 737994  CDC_BIOBOT_ny_551_Treatment plant_post grit re...        Kings
# 737995  CDC_BIOBOT_ny_551_Treatment plant_post grit re...        Kings
# 737996  CDC_BIOBOT_ny_551_Treatment plant_post grit re...        Kings
# 737997  CDC_BIOBOT_ny_551_Treatment plant_post grit re...        Kings
# 737998  CDC_BIOBOT_ny_551_Treatment plant_post grit re...        Kings
# 737999  CDC_BIOBOT_ny_551_Treatment plant_post grit re...        Kings
# 738000  CDC_BIOBOT_ny_551_Treatment plant_post grit re...        Kings
# 738001  CDC_BIOBOT_ny_551_Treatment plant_post grit re...        Kings
# 738002  CDC_BIOBOT_ny_551_Treatment plant_post grit re...        Kings
# 738003  CDC_BIOBOT_ny_551_Treatment plant_post grit re...        Kings
# 738004  CDC_BIOBOT_ny_551_Treatment plant_post grit re...        Kings
# 738005  CDC_BIOBOT_ny_551_Treatment plant_post grit re...        Kings
# 738006  CDC_BIOBOT_ny_551_Treatment plant_post grit re...        Kings
# 738007  CDC_BIOBOT_ny_551_Treatment plant_post grit re...        Kings
# 738008  CDC_BIOBOT_ny_551_Treatment plant_post grit re...        Kings
# 738009  CDC_BIOBOT_ny_551_Treatment plant_post grit re...        Kings
# 738010  CDC_BIOBOT_ny_551_Treatment plant_post grit re...        Kings
# 738011  CDC_BIOBOT_ny_551_Treatment plant_post grit re...        Kings
# 738012  CDC_BIOBOT_ny_551_Treatment plant_post grit re...        Kings
# 738013  CDC_BIOBOT_ny_551_Treatment plant_post grit re...        Kings
# 738014  CDC_BIOBOT_ny_551_Treatment plant_post grit re...        Kings
#
#         population_served  date_start    date_end  ptc_15d  percentile  \
# 737985             758007  2023-07-18  2023-08-01      2.0       40.00
# 737986             758007  2023-07-19  2023-08-02     33.0       40.00
# 737987             758007  2023-07-20  2023-08-03     33.0       40.00
# 737988             758007  2023-07-21  2023-08-04     33.0       40.00
# 737989             758007  2023-07-22  2023-08-05     33.0       40.00
# 737990             758007  2023-07-23  2023-08-06     16.0       39.00
# 737991             758007  2023-07-24  2023-08-07    -26.0       39.00
# 737992             758007  2023-07-25  2023-08-08     -3.0       43.75
# 737993             758007  2023-07-26  2023-08-09     71.0       43.75
# 737994             758007  2023-07-27  2023-08-10     71.0       43.75
# 737995             758007  2023-07-28  2023-08-11     71.0       43.75
# 737996             758007  2023-07-29  2023-08-12     71.0       43.75
# 737997             758007  2023-07-30  2023-08-13     32.0       43.00
# 737998             758007  2023-07-31  2023-08-14     32.0       43.00
# 737999             758007  2023-08-01  2023-08-15     12.0       42.80
# 738000             758007  2023-08-02  2023-08-16     -3.0       42.80
# 738001             758007  2023-08-03  2023-08-17     -3.0       42.80
# 738002             758007  2023-08-04  2023-08-18     -3.0       42.80
# 738003             758007  2023-08-05  2023-08-19     -3.0       42.80
# 738004             758007  2023-08-06  2023-08-20    -17.0       42.60
# 738005             758007  2023-08-07  2023-08-21    -36.0       42.60
# 738006             758007  2023-08-08  2023-08-22    -29.0       42.80
# 738007             758007  2023-08-09  2023-08-23    -24.0       42.80
# 738008             758007  2023-08-10  2023-08-24    -24.0       42.80
# 738009             758007  2023-08-11  2023-08-25    -24.0       42.80
# 738010             758007  2023-08-12  2023-08-26    -24.0       42.80
# 738011             758007  2023-08-13  2023-08-27    -19.0       40.20
# 738012             758007  2023-08-14  2023-08-28    -12.0       40.20
# 738013             758007  2023-08-15  2023-08-29    -12.0       40.20
# 738014             758007  2023-08-16  2023-08-30     -5.0       40.20
#
#        sample_date
# 737985  2023-08-01
# 737986  2023-08-02
# 737987  2023-08-03
# 737988  2023-08-04
# 737989  2023-08-05
# 737990  2023-08-06
# 737991  2023-08-07
# 737992  2023-08-08
# 737993  2023-08-09
# 737994  2023-08-10
# 737995  2023-08-11
# 737996  2023-08-12
# 737997  2023-08-13
# 737998  2023-08-14
# 737999  2023-08-15
# 738000  2023-08-16
# 738001  2023-08-17
# 738002  2023-08-18
# 738003  2023-08-19
# 738004  2023-08-20
# 738005  2023-08-21
# 738006  2023-08-22
# 738007  2023-08-23
# 738008  2023-08-24
# 738009  2023-08-25
# 738010  2023-08-26
# 738011  2023-08-27
# 738012  2023-08-28
# 738013  2023-08-29
# 738014  2023-08-30

# %%
nyc_df[nyc_df.wwtp_id == 551].tail()
# Out:
#               test_date  wrrf_name  covid_conc  per_capita_covid_conc  \
# sample_date
# 2023-07-18   07/19/2023  Owls Head    119688.0             42500000.0
# 2023-07-23   07/24/2023  Owls Head     79008.0             25700000.0
# 2023-07-25   07/26/2023  Owls Head    132672.0             52600000.0
# 2023-07-30   07/31/2023  Owls Head    205752.0             68700000.0
# 2023-08-01   08/02/2023  Owls Head    314400.0                    NaN
#
#             annotation  pop_serv_est  wwtp_id
# sample_date
# 2023-07-18         NaN        906442    551.0
# 2023-07-23         NaN        906442    551.0
# 2023-07-25         NaN        906442    551.0
# 2023-07-30         NaN        906442    551.0
# 2023-08-01         NaN        906442    551.0

# %% [markdown]
# ## Wards Island??

# %%
plt.plot(nyc_df[nyc_df.wrrf_name == "North River"].set_index('test_date').sort_index()['est_percentile'], label='NYC North River')
plt.plot(cdc_df[cdc_df.wwtp_id == 500].set_index('test_date').sort_index()['percentile'], label='CDC 500')
plt.legend()
plt.show()

# %%
plt.plot(nyc_df[nyc_df.wrrf_name == "North River"].set_index('test_date').sort_index()['est_percentile'], label='NYC North River')
plt.plot(cdc_df[cdc_df.wwtp_id == 509].set_index('test_date').sort_index()['percentile'], label='CDC 509')
plt.legend()
plt.show()

# %%
plt.plot(nyc_df[nyc_df.wrrf_name == "Wards Island"].set_index('test_date').sort_index()['est_percentile'], label='NYC Wards')
plt.plot(cdc_df[cdc_df.wwtp_id == 509].set_index('test_date').sort_index()['percentile'], label='CDC 509')
plt.legend()
plt.show()

# %%
plt.plot(nyc_df[nyc_df.wrrf_name == "Wards Island"].set_index('test_date').sort_index()['est_percentile'], label='NYC Wards')
plt.plot(cdc_df[cdc_df.wwtp_id == 500].set_index('test_date').sort_index()['percentile'], label='CDC 500')
plt.legend()
plt.show()

# %% [markdown]
# # Average Adjustment During Overlap Period

# %%
pivot_df = nyc_df[(nyc_df.test_date > "2023-03-01") & (nyc_df.test_date < "2023-04-01") & (nyc_df.covid_conc > 0) & (nyc_df.covid_conc.notnull())].pivot_table(index=['wwtp_id', 'test_date'], columns='Technology', values='covid_conc', aggfunc='mean').reset_index()

# %%
pivot_df['diff'] = pivot_df['dPCR'] / pivot_df['RT-qPCR']

# %%
pivot_df['diff'].mean()
# Out:
# 14.898944514646422

# %% [markdown]
# ## Test Extracting Flow Rate

# %%
nyc_df[nyc_df.per_capita_covid_conc.notnull()].tail()
# Out:
#        Test date       wrrf_name  covid_conc  per_capita_covid_conc  \
# 3957  07/31/2023   Port Richmond    103608.0             40400000.0
# 3958  07/31/2023        Red Hook    105984.0             41200000.0
# 3959  07/31/2023        Rockaway     98232.0             71000000.0
# 3960  07/31/2023  Tallman Island    240960.0            114000000.0
# 3961  07/31/2023    Wards Island    128088.0             83100000.0
#
#                                   annotation  pop_serv_est Technology  \
# 3957                                     NaN        226167       dPCR
# 3958                                     NaN        224029       dPCR
# 3959                                     NaN        120539       dPCR
# 3960  This sample was analyzed in duplicate.        449907       dPCR
# 3961                                     NaN       1201485       dPCR
#
#       test_date  wwtp_id  covid_conc_adj   cum_max  perc_test
# 3957 2023-07-31      552        103608.0  433440.0       23.9
# 3958 2023-07-31      553        105984.0  330720.0       32.0
# 3959 2023-07-31      503         98232.0  941520.0       10.4
# 3960 2023-07-31      505        240960.0  451680.0       53.3
# 3961 2023-07-31        1        128088.0  441360.0       29.0

# %%
nyc_df['pc_covid_conc_wo_pop'] = nyc_df['per_capita_covid_conc'] * nyc_df['pop_serv_est'] 
nyc_df['est_flow_rate'] = nyc_df['pc_covid_conc_wo_pop'] / nyc_df['covid_conc']

# %%
nyc_df[(nyc_df['est_flow_rate'].notnull()) & (nyc_df.wwtp_id == 552)].tail()
# Out:
#        Test date      wrrf_name  covid_conc  per_capita_covid_conc  \
# 3901  07/17/2023  Port Richmond     35808.0             25900000.0
# 3915  07/19/2023  Port Richmond     63024.0             37400000.0
# 3929  07/24/2023  Port Richmond     38520.0             13800000.0
# 3943  07/26/2023  Port Richmond     30504.0             21600000.0
# 3957  07/31/2023  Port Richmond    103608.0             40400000.0
#
#                                   annotation  pop_serv_est Technology  \
# 3901  This sample was analyzed in duplicate.        226167       dPCR
# 3915                                     NaN        226167       dPCR
# 3929                                     NaN        226167       dPCR
# 3943                                     NaN        226167       dPCR
# 3957                                     NaN        226167       dPCR
#
#       test_date  wwtp_id  covid_conc_adj   cum_max  perc_test  \
# 3901 2023-07-17      552         35808.0  433440.0        8.3
# 3915 2023-07-19      552         63024.0  433440.0       14.5
# 3929 2023-07-24      552         38520.0  433440.0        8.9
# 3943 2023-07-26      552         30504.0  433440.0        7.0
# 3957 2023-07-31      552        103608.0  433440.0       23.9
#
#       pc_covid_conc_wo_pop  est_flow_rate
# 3901          5.857725e+12   1.635871e+08
# 3915          8.458646e+12   1.342131e+08
# 3929          3.121105e+12   8.102556e+07
# 3943          4.885207e+12   1.601497e+08
# 3957          9.137147e+12   8.818959e+07

# %% [markdown]
# # Tried rolling before cummax

# %%
def rolling_perc_dPCR(df):
    #df = df[df['technology'] == 'dPCR']
    rolling = df.set_index('test_date').groupby('wwtp_id')['covid_conc_f'].rolling('14D').mean().reset_index().rename(columns={'covid_conc_f':'covid_conc_14d'})
    rolling['cum_max'] = rolling.groupby('wwtp_id')['covid_conc_14d'].cummax()
    rolling['est_percentile'] = np.round((rolling['covid_conc_14d'] / rolling['cum_max']) * 100, 1)
    return rolling

# %%
nyc_df_pivot = nyc_df.pivot_table(index=['test_date', 'wwtp_id'], columns='technology', values='covid_conc', aggfunc='max', fill_value=None)

# Define a preference order for categories
category_preference = ['RT-qPCR', 'dPCR']  # Change the order based on your preference

# Create a new column with preferred values based on the preference order
nyc_df_pivot['covid_conc_f'] = nyc_df_pivot[category_preference].bfill(axis=1).iloc[:, 0]

# Reset the index to convert 'date' back to a column
nyc_df_pivot.reset_index(inplace=True)

# %% [markdown]
# # Comparing sources

# %%
for wwtp_id in [485, 487, 498, 500, 503, 505, 509, 541, 545, 549, 550, 551, 552, 553]:
    df[(df.wwtp_id == wwtp_id)].plot(x="test_date", y=["merged_percentile"], title=wwtp_id)

# %%
df_corr = df
df_corr['percentile'].corr(df_corr['est_percentile'])
# Out:
# 0.750018709236134
